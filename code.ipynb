# %% [markdown]
# # COMPANY BANKRUPTCY PREDICTION

# %% [markdown]
# # IMPORTING REQUIRED LIBRARIES FOR THE PROJECT

# %%
# importing required algorithms
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
data=pd.read_csv('dataset\data.csv')

# %%
#Let's print the first 5 records of the data set
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
#Let's print the last 5 records of the dataset 
data.tail()
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# ...

# %%
#Let's print the column name
data.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
# shape of the dataset
data.shape
# Out:
# (6819, 96)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6814    False
# 6815    False
# 6816    False
# 6817    False
# 6818    False
# Length: 6819, dtype: bool

# %%
#Let's print the total number of duplicated value
data.duplicated().sum()
# Out:
# 0

# %%
#Let's print the unique values in our dataset
data.nunique()
# Out:
# Bankrupt?                                                      2
#  ROA(C) before interest and depreciation before interest    3333
#  ROA(A) before interest and % after tax                     3151
#  ROA(B) before interest and depreciation after tax          3160
#  Operating Gross Margin                                     3781
#                                                             ...
#  Liability to Equity                                        6819
#  Degree of Financial Leverage (DFL)                         6240
#  Interest Coverage Ratio (Interest expense to EBIT)         6240
#  Net Income Flag                                               1
#  Equity to Liability                                        6819
# Length: 96, dtype: int64

# %%
#Let's print the data types in our data
data.dtypes
# Out:
# Bankrupt?                                                     int64
#  ROA(C) before interest and depreciation before interest    float64
#  ROA(A) before interest and % after tax                     float64
#  ROA(B) before interest and depreciation after tax          float64
#  Operating Gross Margin                                     float64
#                                                              ...
#  Liability to Equity                                        float64
#  Degree of Financial Leverage (DFL)                         float64
#  Interest Coverage Ratio (Interest expense to EBIT)         float64
#  Net Income Flag                                              int64
#  Equity to Liability                                        float64
# Length: 96, dtype: object

# %%
#Let's get the overall information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
#Let's check the total number of null values present in our dataset 
data.isnull().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
data.describe().T
# Out:
#                                                      count      mean  \
# Bankrupt?                                           6819.0  0.032263
#  ROA(C) before interest and depreciation before...  6819.0  0.505180
#  ROA(A) before interest and % after tax             6819.0  0.558625
#  ROA(B) before interest and depreciation after tax  6819.0  0.553589
#  Operating Gross Margin                             6819.0  0.607948
# ...                                                    ...       ...
#  Liability to Equity                                6819.0  0.280365
#  Degree of Financial Leverage (DFL)                 6819.0  0.027541
#  Interest Coverage Ratio (Interest expense to E...  6819.0  0.565358
#  Net Income Flag                                    6819.0  1.000000
#  Equity to Liability                                6819.0  0.047578
#
#                                                          std  min       25%  \
# ...

# %%
#Number of days considered
len(data['Bankrupt?'].unique())
# Out:
# 2

# %%
## plot the Correlation matrix
plt.figure(figsize=(20,8))
correlation=data.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ***Axes***:
#
# Y-Axis: The financial metrics or features are listed on the Y-axis. These metrics include various financial ratios and indicators such as 'ROA(B) before interest and depreciation after tax', 'Operating Profit Rate', 'Net Value Per Share (C)', 'Current Ratio', etc.
#
#
# X-Axis: The same financial metrics are listed on the X-axis, creating a matrix where each cell represents the correlation between the corresponding pair of features.
# Heatmap:
#
# The heatmap is colored according to the absolute value of the Pearson correlation coefficients between pairs of features.
#
#
# The color scale ranges from blue to red. Blue represents lower correlation values (closer to 0), while red represents higher correlation values (closer to 1).
# ***Color Bar***:
#
# The color bar on the right side of the heatmap indicates the correlation values with a range from 0 to 1.0.
# The darker the red, the higher the correlation; the darker the blue, the lower the correlation.
#
# ***Diagonal Line***:
#
# The diagonal line from the top-left to the bottom-right of the heatmap is uniformly red, indicating a perfect correlation (correlation coefficient of 1) of each feature with itself.
#
# ***Annotations***:
#
#
# The heatmap includes annotations for each cell showing the absolute correlation value. This helps in identifying the exact correlation values between pairs of features.

# %%
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
x=data.drop(['Bankrupt?'],axis=1)
y=data['Bankrupt?']

# %%
x
# Out:
#       ROA(C) before interest and depreciation before interest  \
# 0                                              0.370594
# 1                                              0.464291
# 2                                              0.426071
# 3                                              0.399844
# 4                                              0.465022
# ...                                                 ...
# 6814                                           0.493687
# 6815                                           0.475162
# 6816                                           0.472725
# 6817                                           0.506264
# 6818                                           0.493053
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# 2                                   0.499019
# 3                                   0.451265
# 4                                   0.538432
# ...

# %%
x.columns
# Out:
# Index([' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
#        ' Realized Sales Gross Profit Growth Rate',
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 6814    0
# 6815    0
# 6816    0
# 6817    0
# 6818    0
# Name: Bankrupt?, Length: 6819, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3, random_state=1)

# %% [markdown]
# ## **K-Best feature selection method to select the best features from all features**

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_regression
from numpy import array

# %%
from sklearn.feature_selection import mutual_info_classif
# determine the mutual information
mutual_info = mutual_info_classif(X_train, Y_train)
mutual_info
# Out:
# array([0.03305181, 0.03895961, 0.03429268, 0.01541721, 0.01573623,
#        0.01792569, 0.03049095, 0.0304729 , 0.02645762, 0.03430257,
#        0.        , 0.        , 0.01055059, 0.00050702, 0.01344603,
#        0.03698048, 0.03369332, 0.03306732, 0.03994636, 0.00695934,
#        0.00262182, 0.02275939, 0.0421062 , 0.01092049, 0.00542005,
#        0.0148793 , 0.01419977, 0.00993228, 0.01651252, 0.03662855,
#        0.01254334, 0.001951  , 0.0103017 , 0.        , 0.03380453,
#        0.0110965 , 0.03145208, 0.03203636, 0.01242202, 0.03739993,
#        0.00175319, 0.02259775, 0.0409333 , 0.00574016, 0.00837158,
#        0.        , 0.00165089, 0.        , 0.00225569, 0.        ,
#        0.00330092, 0.02221069, 0.0009699 , 0.02306454, 0.00260449,
#        0.        , 0.01730556, 0.00556397, 0.00075207, 0.0187991 ,
#        0.01322604, 0.01740238, 0.        , 0.00020155, 0.01750659,
#        0.02375307, 0.        , 0.03274192, 0.03430436, 0.01176367,
# ...

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# Per Share Net profit before tax (Yuan ¥)    0.042106
# Net Income to Stockholder's Equity          0.040986
# Net profit before tax/Paid-in capital       0.040933
# Persistent EPS in the Last Four Seasons     0.039946
# ROA(A) before interest and % after tax      0.038960
#                                               ...
# Operating Expense Rate                      0.000000
# Accounts Receivable Turnover                0.000000
# Research and development expense rate       0.000000
# Quick Ratio                                 0.000000
# Inventory Turnover Rate (times)             0.000000
# Length: 95, dtype: float64

# %%
#let's plot the ordered mutual_info values per feature
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20, 8))
# Out:
# <Axes: >

# %% [markdown]
# X-axis: This axis represents the different features in the dataset. The features are labeled and arranged in descending order of their mutual information values.
#
# Y-axis: This axis represents the mutual information values for each feature. These values are numerical and indicate the level of dependency between each feature and the target variable.
#
# Bar Heights: The height of each bar corresponds to the mutual information value for a given feature. Taller bars indicate higher mutual information, meaning those features are more informative with respect to the target variable.
#
# Ordering: The features are sorted in descending order of their mutual information values, with the most informative features on the left and the least informative on the right.
#
# ***Key Observations***:
#
# ***Top Informative Features***:
#
# The features on the left side, such as 'Per Share Net profit before tax (Yuan ¥)', 'Net Income to Total Operating Revenue', and 'Net Value Per Share (A)', have the highest mutual information values. These features are the most informative with respect to the target variable.
# Less Informative Features:
#
# Features on the right side, such as 'Current Asset Turnover Rate', 'Inventory Turnover Rate (times)', and 'Total assets', have lower mutual information values, indicating they provide less information about the target variable.
# Feature Distribution:
#
# The mutual information values show a gradual decline from left to right, suggesting a range of informativeness among the features.

# %%
from sklearn.feature_selection import SelectKBest
#No we Will select the  top 18 important features
sel_18_cols = SelectKBest(mutual_info_classif, k=18)
sel_18_cols.fit(X_train, Y_train)
X_train.columns[sel_18_cols.get_support()]
# Out:
# Index([' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Continuous interest rate (after tax)', ' Net Value Per Share (B)',
#        ' Net Value Per Share (A)', ' Persistent EPS in the Last Four Seasons',
#        ' Per Share Net profit before tax (Yuan ¥)', ' Net Value Growth Rate',
#        ' Interest Expense Ratio', ' Borrowing dependency',
#        ' Net profit before tax/Paid-in capital',
#        ' Retained Earnings to Total Assets', ' Total income/Total expense',
#        ' Net Income to Total Assets', ' Net Income to Stockholder's Equity',
#        ' Degree of Financial Leverage (DFL)',
#        ' Interest Coverage Ratio (Interest expense to EBIT)'],
#       dtype='object')

# %%
import pandas as pd

# Assuming 'data' is your existing DataFrame that includes the 'label' column
selected_columns = [
    ' ROA(A) before interest and % after tax',
    ' ROA(B) before interest and depreciation after tax',
    ' Continuous interest rate (after tax)', ' Net Value Per Share (B)',
    ' Net Value Per Share (A)', ' Net Value Per Share (C)',
    ' Persistent EPS in the Last Four Seasons',
    ' Per Share Net profit before tax (Yuan ¥)', ' Net Value Growth Rate',
    ' Interest Expense Ratio', ' Borrowing dependency',
    ' Net profit before tax/Paid-in capital',
    ' Retained Earnings to Total Assets', ' Total income/Total expense',
    ' Net Income to Total Assets', " Net Income to Stockholder's Equity",
    ' Degree of Financial Leverage (DFL)',
    ' Interest Coverage Ratio (Interest expense to EBIT)','Bankrupt?'
]

# Create a new DataFrame with the selected columns
df1= data[selected_columns]

# %%
df1.to_csv('newdataset--1.csv')

# %%
df1
# Out:
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...                                       ...
# 6814                                 0.539468
# 6815                                 0.538269
# 6816                                 0.533744
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# ...

# %%
# Visualizing the class imbalance
plt.figure(figsize=(5, 5))
sns.countplot(x='Bankrupt?', data=df1)
plt.title('Class Distribution in Dataset')
plt.show()

# %% [markdown]
# ***Description of the Graph***
#
#
#
# Title: The graph is titled "Class Distribution in Dataset."
# X-axis: The x-axis represents the bankruptcy status with two categories: 0 (Not Bankrupt) and 1 (Bankrupt).
# Y-axis: The y-axis shows the count of instances in each category.
# Bars: There are two bars in the chart:
# The first bar corresponds to the 0 category (Not Bankrupt) and has a significantly higher count, indicating a large number of non-bankrupt instances.
# The second bar corresponds to the 1 category (Bankrupt) and has a much lower count, indicating a smaller number of bankrupt instances.
# Class Imbalance: The chart clearly shows a class imbalance, with the non-bankrupt class (0) being much more prevalent than the bankrupt class (1).

# %%
plt.figure(figsize=(10, 8))
correlation = df1.corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Financial Ratios')
plt.show()

# %% [markdown]
# ***Title: The heatmap is titled "Correlation Heatmap of Financial Ratios."***
#
#
# ***Axes***:
#
#
# The x-axis and y-axis both list the financial ratios and the target variable (Bankrupt?).
# The financial ratios include metrics like ROA(A) before interest and % after tax, ROA(B) before interest and depreciation after tax, Continuous interest rate (after tax), Net Value Per Share (A, B, C), Persistent EPS in the Last Four Seasons, Per Share Net profit before tax (Yuan ¥), Net Value Growth Rate, Interest Expense Ratio, Borrowing dependency, Net profit before tax/Paid-in capital, Retained Earnings to Total Assets, Total income/Total expense, Net Income to Total Assets, Net Income to Stockholder’s Equity, Degree of Financial Leverage (DFL), and Interest Coverage Ratio (Interest expense to EBIT).
#
#
# ***Color Scale***:
#
# The heatmap uses a color scale from blue to red, where blue represents negative correlations, red represents positive correlations, and the intensity of the color indicates the strength of the correlation.
# Annotations: Each cell in the heatmap is annotated with the correlation coefficient value, showing the exact correlation between the pairs of financial ratios.
#
# ***Correlations***:
#
# Strong positive correlations (close to 1) are shown in dark red.
# Strong negative correlations (close to -1) are shown in dark blue.
# Weak or no correlations (close to 0) are shown in lighter colors (light red, light blue, or white).
#
# ***Observations***:
#
# Some ratios show very high positive correlations with each other, such as ROA(A) and ROA(B), Net profit before tax/Paid-in capital and Net Income to Total Assets.
# The Bankrupt? variable has a notable negative correlation with several financial ratios, indicating that as these ratios increase, the likelihood of bankruptcy decreases. For instance, Bankrupt? has a strong negative correlation with Net Income to Total Assets (-0.32) and Net Income to Stockholder’s Equity (-0.30).
# Some financial ratios have negligible correlations with others, indicating little to no linear relationship between them.

# %% [markdown]
# # **again we are dividing the data into x,y**

# %%
X=df1.drop(['Bankrupt?'],axis=1)
Y=df1['Bankrupt?']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
#       ROA(A) before interest and % after tax  \
# 1266                                0.547754
# 5987                                0.534289
# 5832                                0.568251
# 605                                 0.501799
# 3380                                0.569505
# ...                                      ...
# 3184                                0.544102
# 2430                                0.563509
# 748                                 0.557730
# 4233                                0.624727
# 6720                                0.614315
#
#       ROA(B) before interest and depreciation after tax  \
# 1266                                           0.540072
# 5987                                           0.518229
# 5832                                           0.561807
# 605                                            0.489480
# 3380                                           0.562450
# ...                                                 ...
# ...

# %%
Y_train
# Out:
# 1266    0
# 5987    0
# 5832    0
# 605     0
# 3380    0
#        ..
# 3184    0
# 2430    0
# 748     0
# 4233    0
# 6720    0
# Name: Bankrupt?, Length: 4773, dtype: int64

# %%
X_test
# Out:
#       ROA(A) before interest and % after tax  \
# 5246                                0.540395
# 3742                                0.563727
# 491                                 0.547918
# 533                                 0.514828
# 1994                                0.523332
# ...                                      ...
# 2869                                0.574302
# 2120                                0.594200
# 4068                                0.619276
# 5493                                0.561710
# 5929                                0.605048
#
#       ROA(B) before interest and depreciation after tax  \
# 5246                                           0.530275
# 3742                                           0.574335
# 491                                            0.549119
# 533                                            0.498046
# 1994                                           0.523957
# ...                                                 ...
# ...

# %%
Y_test
# Out:
# 5246    0
# 3742    0
# 491     0
# 533     0
# 1994    0
#        ..
# 2869    0
# 2120    0
# 4068    0
# 5493    0
# 5929    0
# Name: Bankrupt?, Length: 2046, dtype: int64

# %% [markdown]
# # **using supervised Machine Learning algorithms**

# %% [markdown]
# # **Decision Tree Classifier**

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc
from sklearn.tree import DecisionTreeClassifier
# Initializing the Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Training the classifier
dt_classifier.fit(X_train, Y_train)

# Predicting on the test set
y_pred = dt_classifier.predict(X_test)

# Calculating accuracy
accuracy = accuracy_score(Y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.96

# %%
# Generating confusion matrix
conf_matrix = confusion_matrix(Y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[1933   35]
#  [  50   28]]

# %%
# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# True Positives (TP): The model correctly predicted positive instances (in this case, class 1).
#
# Value: 25
#
# Interpretation: There are 25 instances where the model correctly predicted the positive class.
# False Positives (FP): The model incorrectly predicted positive instances (class 1) when the actual label was negative (class 0).
#
# Value: 49
#
# Interpretation: There are 49 instances where the model predicted the positive class, but it was actually negative.
# True Negatives (TN): The model correctly predicted negative instances (class 0).
#
# Value: 1926
#
# Interpretation: There are 1926 instances where the model correctly predicted the negative class.
# False Negatives (FN): The model incorrectly predicted negative instances (class 0) when the actual label was positive (class 1).
#
# Value: 46
#
# Interpretation: There are 46 instances where the model predicted the negative class, but it was actually positive.

# %%
# Generating classification report
class_report = classification_report(Y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1968
#            1       0.44      0.36      0.40        78
#
#     accuracy                           0.96      2046
#    macro avg       0.71      0.67      0.69      2046
# weighted avg       0.95      0.96      0.96      2046

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming y_pred_prob contains probability scores of the positive class
y_pred_prob = dt_classifier.predict_proba(X_test)[:, 1]

# Compute ROC curve and ROC area
fpr, tpr, _ = roc_curve(Y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plotting the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange',
         lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Decision tree')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ***Area Under the Curve (AUC)***:
#
# AUC value is noted as 0.66.
# The AUC measures the entire two-dimensional area underneath the entire ROC curve from (0,0) to (1,1).
# It provides an aggregate measure of performance across all possible classification thresholds. The higher the AUC, the better the model is at distinguishing between the classes.
# AUC values range from 0 to 1. A model with 100% correct predictions has an AUC of 1

# %% [markdown]
# # **Naive_Bayes**

# %%
from sklearn.naive_bayes import GaussianNB

# Initialize Naive Bayes Classifier
nb_classifier = GaussianNB()

# Train the classifier
nb_classifier.fit(X_train, Y_train)

# Predict on the test set
y_pred_nb = nb_classifier.predict(X_test)

# Calculate accuracy
accuracy_nb = accuracy_score(Y_test, y_pred_nb)
print(f'Naive Bayes Accuracy: {accuracy_nb:.2f}')
# Out:
# Naive Bayes Accuracy: 0.96

# %%
# Confusion matrix
conf_matrix_nb = confusion_matrix(Y_test, y_pred_nb)
print('Naive Bayes Confusion Matrix:')
print(conf_matrix_nb)
# Out:
# Naive Bayes Confusion Matrix:
# [[1968    0]
#  [  78    0]]

# %%
# Plotting the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_nb, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Naive Bayes Confusion Matrix')
plt.show()

# %% [markdown]
# The matrix shows two classes, 0 and 1.
#
# **True Negatives (TN)**:
# The model correctly predicted 1975 instances as class 0, where they actually belong to class 0. This is shown in the top left corner of the matrix.
#
# **False Negatives (FN)**:
# The model incorrectly predicted 71 instances as class 0, where they actually belong to class 1. This is shown in the bottom left corner of the matrix.
#
# **True Positives (TP) and False Positives (FP)**:
# Both are 0 for class 1, indicating that the model did not predict any instances as class 1. This results in no True Positives or False Positives for class 1, as seen in the right column of the matrix.

# %%
# Generating classification report
class_report = classification_report(Y_test, y_pred_nb)
print('Classification Report:')
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1968
#            1       0.00      0.00      0.00        78
#
#     accuracy                           0.96      2046
#    macro avg       0.48      0.50      0.49      2046
# weighted avg       0.93      0.96      0.94      2046
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# ROC Curve for Naive Bayes
y_pred_prob_nb = nb_classifier.predict_proba(X_test)[:, 1]
fpr_nb, tpr_nb, _ = roc_curve(Y_test, y_pred_prob_nb)
roc_auc_nb = auc(fpr_nb, tpr_nb)

plt.figure(figsize=(8, 6))
plt.plot(fpr_nb, tpr_nb, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc_nb:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Naive Bayes')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# The graph displayed is a Receiver Operating Characteristic (ROC) curve for a Naive Bayes classifier. This curve plots the True Positive Rate (TPR) against the False Positive Rate (FPR) at various threshold settings. The ROC curve is shown in orange, and it exhibits a somewhat jagged ascent, stabilizing close to the top-right corner of the plot. The area under the curve (AUC) is 0.88, which indicates a good level of discrimination ability by the classifier. The blue dashed line represents the diagonal line of no-discrimination, which serves as a baseline. The further the orange curve is above this line, the better the model's performance. In this case, the Naive Bayes model performs significantly better than random guessing, as evidenced by the substantial area between the curve and the diagonal.

# %% [markdown]
# # **Hybrid Algorithms(Decisiontree+Guassian)**

# %%
from sklearn.ensemble import VotingClassifier

# Initialize classifiers
dt_classifier = DecisionTreeClassifier(random_state=42)
nb_classifier = GaussianNB()

# Voting classifier for combining Decision Tree and Naive Bayes
hybrid_classifier = VotingClassifier(estimators=[
    ('decision_tree', dt_classifier),
    ('naive_bayes', nb_classifier)
], voting='soft')

# Train the classifier
hybrid_classifier.fit(X_train, Y_train)

# Predict on the test set
y_pred_hybrid = hybrid_classifier.predict(X_test)

# Calculate accuracy
accuracy_hybrid = accuracy_score(Y_test, y_pred_hybrid)
print(f'Hybrid DT-NB Accuracy: {accuracy_hybrid:.2f}')
# Out:
# Hybrid DT-NB Accuracy: 0.96

# %%
# Confusion matrix
conf_matrix_hybrid = confusion_matrix(Y_test, y_pred_hybrid)
print('Hybrid DT-NB Confusion Matrix:')
print(conf_matrix_hybrid)
# Out:
# Hybrid DT-NB Confusion Matrix:
# [[1933   35]
#  [  50   28]]

# %%
conf_matrix_hybrid = confusion_matrix(Y_test, y_pred_hybrid)
sns.heatmap(conf_matrix_hybrid, annot=True, fmt='d', cmap='Blues')
plt.title('Hybrid DT-NB Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# True Positives (TP): The top left cell (1926) represents the count of positive cases correctly identified by the model.
#
# False Negatives (FN): The bottom left cell (46) shows the count of positive cases that were incorrectly labeled as negative by the model.
#
# False Positives (FP): The top right cell (49) indicates the count of negative cases that were incorrectly labeled as positive.
#
# True Negatives (TN): The bottom right cell (25) represents the count of negative cases correctly identified.

# %%
# Assuming the hybrid model can produce probability estimates
y_pred_prob_hybrid = hybrid_classifier.predict_proba(X_test)[:, 1]
fpr_hybrid, tpr_hybrid, _ = roc_curve(Y_test, y_pred_prob_hybrid)
roc_auc_hybrid = auc(fpr_hybrid, tpr_hybrid)

plt.figure(figsize=(8, 6))
plt.plot(fpr_hybrid, tpr_hybrid, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc_hybrid:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Hybrid DT-NB')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# True Positive Rate (also known as recall or sensitivity) measures the proportion of actual positives that are correctly identified as such.
#
# False Positive Rate measures the proportion of actual negatives that are incorrectly classified as positives.
#
# The orange line represents the ROC curve for the Hybrid DT-NB model, which shows the trade-off between the True Positive Rate and False Positive Rate at different thresholds. The area under the curve (AUC) is a measure of the model's ability to distinguish between the classes and is indicated as 0.89. This value ranges from 0 to 1, where a value closer to 1 indicates a better model that can accurately distinguish between the positive and negative classes.
#
# The blue dashed line represents a no-skill classifier that acts as a baseline, where the true positive rate equals the false positive rate. The ROC curve lying above this line suggests that the classifier provides a better-than-random prediction for the classes. The closer the ROC curve is to the upper left corner, the higher the overall accuracy of the test in correctly classifying the cases, reflecting a desirable outcome in most diagnostic settings.

# %%
from sklearn.metrics import classification_report
# Example: Generating classification report
report = classification_report(Y_test, y_pred_hybrid)
# Example: Printing the classification report
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1968
#            1       0.44      0.36      0.40        78
#
#     accuracy                           0.96      2046
#    macro avg       0.71      0.67      0.69      2046
# weighted avg       0.95      0.96      0.96      2046

# %% [markdown]
# # ***Hybrid Algorithm of XGBoost and ANN***

# %%
from xgboost import XGBClassifier
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score

# Define and train XGBoost model
xgb_model = XGBClassifier()
xgb_model.fit(X_train, Y_train)

# Define and train ANN model
ann_model = Sequential([
    Dense(128, activation='relu', input_dim=X_train.shape[1]),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])
ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
ann_model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=0)  # Adjust verbose as needed

# Evaluate XGBoost model
xgb_y_pred = xgb_model.predict(X_test)
xgb_accuracy = accuracy_score(Y_test, xgb_y_pred)
print(f'XGBoost Model Accuracy: {xgb_accuracy:.2f}')

# Evaluate ANN model
ann_y_pred_prob = ann_model.predict(X_test)  # Predict probabilities
ann_y_pred = (ann_y_pred_prob > 0.5).astype(int).flatten()  # Convert probabilities to binary class labels
ann_accuracy = accuracy_score(Y_test, ann_y_pred)
print(f'ANN Model Accuracy: {ann_accuracy:.2f}')

# Combine predictions (example ensemble)
combined_y_pred = (xgb_y_pred + ann_y_pred) // 2  # Simple averaging for binary classification
combined_accuracy = accuracy_score(Y_test, combined_y_pred)
print(f'Combined Model Accuracy: {combined_accuracy:.2f}')
# Out:
# XGBoost Model Accuracy: 0.96
# 64/64 [==============================] - 0s 1ms/step
# ANN Model Accuracy: 0.96
# Combined Model Accuracy: 0.96

# %%
# Generate confusion matrix for combined predictions
conf_matrix_combined = confusion_matrix(Y_test, combined_y_pred)
print('Confusion Matrix for Combined Model:')
print(conf_matrix_combined)
# Out:
# Confusion Matrix for Combined Model:
# [[1968    0]
#  [  78    0]]

# %%
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_combined, annot=True, cmap='Blues', fmt='d', cbar=False,
            xticklabels=['Predicted Negative', 'Predicted Positive'],
            yticklabels=['Actual Negative', 'Actual Positive'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix for Combined Model')
plt.show()

# %% [markdown]
# Top Left Cell (1973): True Negatives (TN) - The model correctly predicted the negative class.
#
# Top Right Cell (2): False Positives (FP) - The model incorrectly predicted the positive class when it was actually negative.
#
# Bottom Left Cell (67): False Negatives (FN) - The model incorrectly predicted the negative class when it was actually positive.
#
# Bottom Right Cell (4): True Positives (TP) - The model correctly predicted the positive class.
#
# The labels along the x-axis represent the predicted classes, and the labels along the y-axis represent the actual classes. The matrix uses shades of blue to indicate the count of predictions, with darker shades typically indicating higher numbers. This type of visualization helps in understanding the model's accuracy, indicating how well the model is at distinguishing between the classes. In this case, the model shows a strong ability to identify negative cases but struggles somewhat with identifying positive cases, as reflected by the relatively small number of true positives (4) compared to false negatives (67).

# %%
from sklearn.metrics import classification_report

# Generate classification report for combined predictions
class_report_combined = classification_report(Y_test, combined_y_pred)
print('Classification Report for Combined Model:')
print(class_report_combined)
# Out:
# Classification Report for Combined Model:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1968
#            1       0.00      0.00      0.00        78
#
#     accuracy                           0.96      2046
#    macro avg       0.48      0.50      0.49      2046
# weighted avg       0.93      0.96      0.94      2046
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.metrics import roc_curve, auc

# Calculate ROC curve and AUC for XGBoost model
xgb_y_prob = xgb_model.predict_proba(X_test)[:, 1]
fpr_xgb, tpr_xgb, _ = roc_curve(Y_test, xgb_y_prob)
roc_auc_xgb = auc(fpr_xgb, tpr_xgb)

# Calculate probabilities for ANN model
ann_y_prob = ann_model.predict(X_test)
fpr_ann, tpr_ann, _ = roc_curve(Y_test, ann_y_prob)
roc_auc_ann = auc(fpr_ann, tpr_ann)

# Calculate ROC curve and AUC for Combined model (assuming simple averaging)
combined_y_prob = (xgb_y_prob + ann_y_prob.flatten()) / 2
fpr_combined, tpr_combined, _ = roc_curve(Y_test, combined_y_prob)
roc_auc_combined = auc(fpr_combined, tpr_combined)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr_xgb, tpr_xgb, color='blue', lw=2, label=f'XGBoost (AUC = {roc_auc_xgb:.2f})')
plt.plot(fpr_ann, tpr_ann, color='green', lw=2, label=f'ANN (AUC = {roc_auc_ann:.2f})')
plt.plot(fpr_combined, tpr_combined, color='purple', lw=2, label=f'Combined (AUC = {roc_auc_combined:.2f})')
plt.plot([0, 1], [0, 1], color='black', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# 64/64 [==============================] - 0s 1ms/step

# %% [markdown]
# XGBoost (Blue Line):
# Achieves the highest performance among the models with an Area Under Curve (AUC) of 0.92, indicating excellent discrimination between positive and negative classes.
#
# ANN (Green Line):
# Shows a lower performance compared to XGBoost, with an AUC of 0.88, reflecting good but not excellent capability in distinguishing between the classes.
#
# Combined Model (Purple Line):
# The combined model, which averages the probabilities of XGBoost and ANN, shows a performance close to XGBoost with an AUC of 0.91, suggesting that the combination approach effectively leverages the strengths of both individual models.
#
# The plot includes a diagonal dashed line representing a random classifier (AUC = 0.5); ideal models' curves should be as far away from this line as possible, moving towards the top left corner of the plot. This graph indicates that all three models perform well above randomness, particularly the XGBoost and combined models, which approach the ideal top left corner.

# %% [markdown]
# # ***CNN(convolutional neural network) algorithm to the dataset***

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from keras.optimizers import Adam
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np

# Assuming X and Y are already defined
X = np.expand_dims(X, axis=2)

# Split the data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Define the 1D CNN model architecture
cnn_model = Sequential([
    Conv1D(32, 3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    MaxPooling1D(2),
    Conv1D(64, 3, activation='relu'),
    MaxPooling1D(2),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
cnn_model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = cnn_model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=1, validation_split=0.2)

# Predict using the trained model
cnn_y_pred = (cnn_model.predict(X_test) > 0.5).astype(int).flatten()

# Calculate the accuracy
cnn_accuracy = accuracy_score(Y_test, cnn_y_pred)
print(f'CNN Model Accuracy: {cnn_accuracy:.2f}')
# Out:
# Epoch 1/10
# 137/137 [==============================] - 2s 6ms/step - loss: 0.1888 - accuracy: 0.9560 - val_loss: 0.1457 - val_accuracy: 0.9661
# Epoch 2/10
# 137/137 [==============================] - 0s 3ms/step - loss: 0.1323 - accuracy: 0.9698 - val_loss: 0.1432 - val_accuracy: 0.9661
# Epoch 3/10
# 137/137 [==============================] - 1s 4ms/step - loss: 0.1312 - accuracy: 0.9698 - val_loss: 0.1403 - val_accuracy: 0.9661
# Epoch 4/10
# 137/137 [==============================] - 1s 4ms/step - loss: 0.1286 - accuracy: 0.9698 - val_loss: 0.1363 - val_accuracy: 0.9661
# Epoch 5/10
# 137/137 [==============================] - 0s 4ms/step - loss: 0.1242 - accuracy: 0.9698 - val_loss: 0.1387 - val_accuracy: 0.9661
# Epoch 6/10
# 137/137 [==============================] - 0s 4ms/step - loss: 0.1180 - accuracy: 0.9695 - val_loss: 0.1309 - val_accuracy: 0.9661
# Epoch 7/10
# ...

# %%
# Calculate the confusion matrix
cm = confusion_matrix(Y_test, cnn_y_pred)

# %%
cm
# Out:
# array([[1311,    2],
#        [  49,    2]], dtype=int64)

# %%
# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ***Axes Labels***:
#
# X-axis: Labeled as "Predicted", it represents the predicted classes by the model.
# Y-axis: Labeled as "Actual", it represents the true classes.
#
# ***Classes***:
#
# The plot distinguishes between two classes: "Negative" and "Positive".
# "Negative" typically means the absence of the condition or class, while "Positive" means the presence.
# Values:
#
# Top-left (1309): True Negatives (TN) - The model correctly predicted the negative class.
# Top-right (4): False Positives (FP) - The model incorrectly predicted the positive class when it was actually negative.
# Bottom-left (44): False Negatives (FN) - The model incorrectly predicted the negative class when it was actually positive.
# Bottom-right (7): True Positives (TP) - The model correctly predicted the positive class.
# Color Intensity:
#
# The color intensity in each cell represents the count of instances for that classification outcome. Darker shades indicate higher counts.
# The color bar on the right indicates the scale of the values.
# Interpretation:
#
# The model has a high number of true negatives (1309), indicating it is quite good at correctly identifying negative cases.
# The number of false positives (4) is very low, suggesting the model rarely misclassifies negative cases as positive.
# The number of true positives (7) is quite low, indicating that the model struggles to correctly identify positive cases.
# The number of false negatives (44) is relatively high compared to the true positives, which means the model frequently misses positive cases.

# %%
# Print the classification report
print(classification_report(Y_test, cnn_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1313
#            1       0.50      0.04      0.07        51
#
#     accuracy                           0.96      1364
#    macro avg       0.73      0.52      0.53      1364
# weighted avg       0.95      0.96      0.95      1364

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


# Calculate the ROC curve and AUC
fpr, tpr, thresholds = roc_curve(Y_test, cnn_y_pred)
roc_auc = roc_auc_score(Y_test, cnn_y_pred)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ***Axes***:
#
# X-axis (False Positive Rate): This axis represents the proportion of negative instances that were incorrectly classified as positive. It ranges from 0 to 1, where 0 indicates no false positives and 1 indicates all negatives are classified as positive.
#
# Y-axis (True Positive Rate): This axis represents the proportion of positive instances that were correctly classified as positive (also known as sensitivity or recall). It ranges from 0 to 1, where 0 indicates no true positives and 1 indicates all positives are correctly classified.
#
# ***ROC Curve (Blue Line)***:
#
# The blue line represents the ROC curve, which plots the true positive rate (TPR) against the false positive rate (FPR) at various threshold settings.
# The curve typically starts at the origin (0,0) and ends at the point (1,1).
# The shape and position of the curve indicate the performance of the classifier. A curve that bows closer to the top-left corner indicates a better performance.
#
# ***Diagonal Line (Gray Dashed Line)***:
#
# The gray dashed line represents a random classifier. It follows the line y=x, where the true positive rate equals the false positive rate.
# This line serves as a baseline for evaluating the ROC curve. Any classifier performing above this line is better than random chance.
#
# ***AUC (Area Under the Curve)***:
#
# The legend includes the AUC value, which is a single scalar value summarizing the performance of the classifier.
# The AUC ranges from 0 to 1, with 1 indicating a perfect classifier and 0.5 indicating a classifier no better than random chance.
# In this plot, the AUC is indicated in the legend (e.g., ROC curve (area = 0.90)). A higher AUC value indicates better classifier performance.

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


# Reshape X to be (num_samples, timesteps, features) for LSTM
X = np.reshape(X, (X.shape[0], X.shape[1], 1))

# Split the data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Define the LSTM model architecture
lstm_model = Sequential([
    LSTM(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
lstm_model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = lstm_model.fit(X_train, Y_train, epochs=10, batch_size=32, verbose=1, validation_split=0.2)

# Predict using the trained model
lstm_y_pred = (lstm_model.predict(X_test) > 0.5).astype(int).flatten()

# Calculate the accuracy
lstm_accuracy = accuracy_score(Y_test, lstm_y_pred)
print(f'LSTM Model Accuracy: {lstm_accuracy:.2f}')
# Out:
# Epoch 1/10
# 137/137 [==============================] - 4s 11ms/step - loss: 0.2067 - accuracy: 0.9698 - val_loss: 0.1398 - val_accuracy: 0.9661
# Epoch 2/10
# 137/137 [==============================] - 1s 7ms/step - loss: 0.1301 - accuracy: 0.9698 - val_loss: 0.1377 - val_accuracy: 0.9661
# Epoch 3/10
# 137/137 [==============================] - 1s 7ms/step - loss: 0.1271 - accuracy: 0.9698 - val_loss: 0.1389 - val_accuracy: 0.9661
# Epoch 4/10
# 137/137 [==============================] - 1s 7ms/step - loss: 0.1284 - accuracy: 0.9698 - val_loss: 0.1400 - val_accuracy: 0.9661
# Epoch 5/10
# 137/137 [==============================] - 1s 7ms/step - loss: 0.1277 - accuracy: 0.9698 - val_loss: 0.1357 - val_accuracy: 0.9661
# Epoch 6/10
# 137/137 [==============================] - 1s 7ms/step - loss: 0.1270 - accuracy: 0.9698 - val_loss: 0.1376 - val_accuracy: 0.9661
# Epoch 7/10
# ...

# %%
# Confusion Matrix
cm = confusion_matrix(Y_test, lstm_y_pred)
print('Confusion Matrix:')
print(cm)
# Out:
# Confusion Matrix:
# [[1313    0]
#  [  51    0]]

# %%
# Plot Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ***Axes***:
#
# X-axis (Predicted): This axis represents the predicted classes by the model.
# Class 0: Represents the negative class (non-event or non-positive).
# Class 1: Represents the positive class (event or positive).
# Y-axis (True): This axis represents the true classes from the test data.
# Class 0: Represents the true negative class.
# Class 1: Represents the true positive class.
#
# ***Heatmap Representation***:
#
# Color Scale (Blues): The color intensity represents the count of observations in each cell of the confusion matrix.
# Darker shades of blue represent higher counts.
# Lighter shades represent lower counts.
#
# ***Cells***:
#
# Top-left cell (1313):
# Represents the number of true negatives (TN).
# The model correctly predicted 1313 instances as class 0 (negative), which were actually class 0.
# Top-right cell (0):
# Represents the number of false positives (FP).
# The model incorrectly predicted 0 instances as class 1 (positive), which were actually class 0.
# Bottom-left cell (51):
# Represents the number of false negatives (FN).
# The model incorrectly predicted 51 instances as class 0 (negative), which were actually class 1.
# Bottom-right cell (0):
# Represents the number of true positives (TP).
# The model correctly predicted 0 instances as class 1 (positive), which were actually class 1.
# Annotations:
#
# Each cell is annotated with the count of observations, making it easy to read the exact numbers.
# Color Bar:
#
# On the right side of the plot, there is a color bar indicating the color scale used in the heatmap.
# The color bar helps to interpret the intensity of the colors in the heatmap.
#
#
# ***Interpretation***:
# True Negatives (TN):
# The model correctly identified 1313 instances as class 0, indicating a high accuracy in predicting the negative class.
# True Positives (TP):
# The model did not correctly identify any instances as class 1, indicating poor performance in predicting the positive class.
# False Negatives (FN):
# There are 51 instances where the model failed to identify the positive class, predicting them as negative.
# False Positives (FP):
# There are no false positives, meaning the model did not incorrectly classify any negative instances as positive.
# Overall Performance:
# High True Negatives: The model is very good at predicting negative instances.
# Low True Positives: The model fails to identify positive instances, which suggests that the model might be biased towards predicting the negative class.
# Areas for Improvement: The model needs improvement in detecting true positive instances, which could involve adjusting the model, balancing the dataset, or tuning the thresholds used for classification.

# %%
# Classification Report
cr = classification_report(Y_test, lstm_y_pred)
print('Classification Report:')
print(cr)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1313
#            1       0.00      0.00      0.00        51
#
#     accuracy                           0.96      1364
#    macro avg       0.48      0.50      0.49      1364
# weighted avg       0.93      0.96      0.94      1364
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(Y_test, lstm_y_pred)
roc_auc = roc_auc_score(Y_test, lstm_y_pred)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ***Axes***:
#
# X-axis (False Positive Rate): This axis represents the proportion of actual negative cases that are incorrectly classified as positive by the model. It ranges from 0 to 1.
# Y-axis (True Positive Rate): This axis represents the proportion of actual positive cases that are correctly classified as positive by the model (also known as sensitivity or recall). It ranges from 0 to 1.
#
# ***ROC Curve (Blue Line)***:
#
# The blue line represents the ROC curve, which plots the true positive rate (TPR) against the false positive rate (FPR) at various threshold settings.
# The ROC curve is a graphical representation of a classifier’s ability to distinguish between positive and negative classes.
#
# ***Diagonal Line (Gray Dashed Line)***:
#
# The gray dashed line represents a random classifier that makes predictions based on random chance.
# This line follows the equation y = x, indicating that the true positive rate equals the false positive rate.
# It serves as a baseline to evaluate the performance of the ROC curve. Any model performing above this line is better than random guessing.
#
# ***AUC (Area Under the Curve)***:
#
# The legend includes the AUC value, which is a single scalar value summarizing the overall performance of the classifier.
# The AUC ranges from 0 to 1, with 1 indicating a perfect classifier and 0.5 indicating a classifier that performs no better than random chance.
# In this plot, the AUC is indicated as 0.50, which suggests that the classifier performs no better than random guessing.
#
# ***Annotations and Elements***:
# ***Figure Size***:
#
# The plot has a figure size of 8x6 inches, providing a clear and spacious visualization.
#
# ***Labels and Title***:
#
# The x-axis is labeled as 'False Positive Rate.'
# The y-axis is labeled as 'True Positive Rate.'
# The plot is titled 'Receiver Operating Characteristic (ROC) Curve,' clearly stating the purpose of the plot.
# Legend:
#
# The legend is located at the lower right corner of the plot, providing context for the ROC curve and the AUC value.
# Limits:
#
# The x-axis limit is set from 0.0 to 1.0.
# The y-axis limit is set from 0.0 to 1.05, slightly exceeding 1 to ensure clarity and avoid cramping.
# Interpretation:
#
# ROC Curve Analysis:
#
# The ROC curve in this plot follows the diagonal line y = x, which indicates that the classifier’s performance is equivalent to random guessing.
# The curve does not bow towards the top-left corner, which would indicate better performance.
#
# AUC Interpretation:
#
# The AUC value is 0.50, reinforcing that the model has no discrimination ability and performs as poorly as a random classifier.
#
# Overall Performance:
# Poor Classifier Performance:
# The ROC curve and AUC value both indicate that the LSTM model fails to distinguish between the positive and negative classes.
#
# Potential Issues:
# The model might be underfitting, possibly due to insufficient training, inadequate feature representation, or improper model architecture.

# %% [markdown]
# # ***PREDICTION***

# %%
# Flatten the last dimension for DecisionTreeClassifier
X_train_flat = X_train.reshape((X_train.shape[0], -1))
X_test_flat = X_test.reshape((X_test.shape[0], -1))

# Create the sample input data for prediction
abc = np.array([[0.424389446140427,0.40574977247176,0.780984850207341,0.147949938898487,0.147949938898487,0.147949938898487,0.16914058806845,0.138736160277171,0.000326977269203,0.629951302036958,0.390284354359258,0.137757333534424,0.903224771166726,0.0020216130120256,0.716845343217827,0.82789021403512,0.0266006307607414,0.564050112276341]])

# Ensure the sample input data is 2D
abc_flat = abc.reshape((abc.shape[0], -1))

# Define the DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Train the classifier
dt_classifier.fit(X_train_flat, Y_train)

# Predict on the sample input data
result = dt_classifier.predict(abc_flat)
if result == 0:
    print('Bankruptcy was not done')
else:
    print('Bankruptcy was done')
# Out:
# Bankruptcy was done

# %%
# Flatten the last dimension for DecisionTreeClassifier
X_train_flat = X_train.reshape((X_train.shape[0], -1))
X_test_flat = X_test.reshape((X_test.shape[0], -1))

# Create the sample input data for prediction
abc = np.array([[0.545137374618404,0.5432839017078,0.781598185090152,0.184189456828621,0.184189456828621,0.184189456828621,0.218398411647915,0.173156586578293,0.0004527224008151,0.630914987465925,0.370253398138601,0.172158962370862,0.935200209287994,0.0022739602931646,0.803647289792132,0.840486633095349,0.0268906304546816,0.565591901310376]])

# Ensure the sample input data is 2D
abc_flat = abc.reshape((abc.shape[0], -1))

# Define the DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier(random_state=42)

# Train the classifier
dt_classifier.fit(X_train_flat, Y_train)

# Predict on the sample input data
result = dt_classifier.predict(abc_flat)
if result == 0:
    print('Bankruptcy was not done')
else:
    print('Bankruptcy was done')
# Out:
# Bankruptcy was not done
